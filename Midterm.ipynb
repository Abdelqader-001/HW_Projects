# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("epldata_final.csv")

# %%
data_most_valuable=data.sort_values('market_value',ascending = False)

# %%
data_most_valuable.head()  # the most valuable players
# Out:
#                 name               club  age position  position_cat  \
# 92       Eden Hazard            Chelsea   26       LW             1
# 263       Paul Pogba  Manchester+United   24       CM             2
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 240  Kevin De Bruyne    Manchester+City   26       AM             1
# 241    Sergio Aguero    Manchester+City   29       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 92           75.0        4220       10.5   2.30%         224     2.0
# 263          75.0        7435        8.0  19.50%         115     2.0
# 0            65.0        4329       12.0  17.10%         264     3.0
# 240          65.0        2252       10.0  17.50%         199     2.0
# 241          65.0        4046       11.5   9.70%         175     3.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 92      Belgium            0        3        5         1            0
# ...

# %%
data_most_popular_fpl_value=data.sort_values('fpl_value',ascending = False)

# %%
data_most_popular_fpl_value
# Out:
#                      name               club  age position  position_cat  \
# 377            Harry Kane          Tottenham   23       CF             1
# 0          Alexis Sanchez            Arsenal   28       LW             1
# 260         Romelu Lukaku  Manchester+United   24       CF             1
# 241         Sergio Aguero    Manchester+City   29       CF             1
# 251         Gabriel Jesus    Manchester+City   20       CF             1
# 92            Eden Hazard            Chelsea   26       LW             1
# 27    Alexandre Lacazette            Arsenal   26       CF             1
# 93            Diego Costa            Chelsea   28       CF             1
# 240       Kevin De Bruyne    Manchester+City   26       AM             1
# 378     Christian Eriksen          Tottenham   25       AM             1
# 376             Dele Alli          Tottenham   21       CM             2
# 215            Sadio Mane          Liverpool   25       LW             1
# ...

# %%
data_most_popular_page_views=data.sort_values('page_views',ascending = False)

# %%
data_most_popular_page_views
# Out:
#                       name               club  age position  position_cat  \
# 143           Wayne Rooney            Everton   31       SS             1
# 263             Paul Pogba  Manchester+United   24       CM             2
# 376              Dele Alli          Tottenham   21       CM             2
# 93             Diego Costa            Chelsea   28       CF             1
# 1               Mesut Ozil            Arsenal   28       AM             1
# 0           Alexis Sanchez            Arsenal   28       LW             1
# 251          Gabriel Jesus    Manchester+City   20       CF             1
# 92             Eden Hazard            Chelsea   26       LW             1
# 377             Harry Kane          Tottenham   23       CF             1
# 241          Sergio Aguero    Manchester+City   29       CF             1
# 104         N%27Golo Kante            Chelsea   26       DM             2
# 260          Romelu Lukaku  Manchester+United   24       CF             1
# ...

# %%
data_most_popular_fpl_sel=data.sort_values('fpl_sel',ascending = False)

# %%
data_most_popular_fpl_sel
# Out:
#                          name               club  age position  position_cat  \
# 241             Sergio Aguero    Manchester+City   29       CF             1
# 51              Asmir Begovic        Bournemouth   30       GK             4
# 101                   Willian            Chelsea   28       RW             1
# 381            Jan Vertonghen          Tottenham   30       CB             3
# 245                Leroy Sane    Manchester+City   21       LW             1
# 351          Gylfi Sigurdsson            Swansea   27       AM             1
# 56              Uwe Hunemeier  Brighton+and+Hove   31       CB             3
# 396           Ã‰tienne Capoue            Watford   29       DM             2
# 97                      Pedro            Chelsea   29       RW             1
# 267             Ander Herrera  Manchester+United   27       CM             2
# 100             Cesc Fabregas            Chelsea   30       CM             2
# ...

# %%
df_market_value=data['market_value'] 
df_market_value
# Out:
# 0      65.00
# 1      50.00
# 2       7.00
# 3      20.00
# 4      22.00
# 5      30.00
# 6      22.00
# 7      13.00
# 8      30.00
# 9      10.00
# 10     35.00
# 11     22.00
# 12     18.00
# 13     35.00
# 14     15.00
# 15     13.00
# 16     10.00
# 17     12.00
# 18     15.00
# 19      7.00
# 20     10.00
# 21     15.00
# 22      1.00
# 23      7.00
# 24      5.00
# 25      6.00
# 26     15.00
# 27     40.00
# 28      8.00
# 29      5.00
#        ...
# 431    10.00
# 432     4.00
# 433     3.00
# 434     2.50
# 435     1.50
# 436     0.25
# 437     1.50
# 438     1.00
# 439     8.00
# 440    15.00
# 441    18.00
# 442    10.00
# 443     7.00
# 444    18.00
# 445    12.00
# 446     7.00
# 447     2.50
# 448     2.00
# 449    10.00
# 450     8.00
# 451    12.00
# 452     9.00
# 453    12.00
# 454     9.00
# 455     7.00
# 456     5.00
# 457     7.00
# 458     4.50
# 459     1.00
# 460    10.00
# Name: market_value, Length: 461, dtype: float64

# %%
distribution_plot=plt.scatter( df_market_value.index,df_market_value)  # market value distribution

# %%
distribution_histgram=data.hist(column={df_market_value})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-13bb3ed35ebd> in <module>
# ----> 1 distribution_histgram=data.hist(column={df_market_value})
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
df_market_value_age=data[['market_value','age']]

# %%
df_market_value_age
# Out:
#      market_value  age
# 0           65.00   28
# 1           50.00   28
# 2            7.00   35
# 3           20.00   28
# 4           22.00   31
# 5           30.00   22
# 6           22.00   30
# 7           13.00   31
# 8           30.00   25
# 9           10.00   21
# 10          35.00   24
# 11          22.00   23
# 12          18.00   25
# 13          35.00   26
# 14          15.00   26
# 15          13.00   26
# 16          10.00   27
# 17          12.00   32
# 18          15.00   26
# 19           7.00   21
# 20          10.00   25
# 21          15.00   28
# 22           1.00   24
# 23           7.00   28
# 24           5.00   25
# 25           6.00   32
# 26          15.00   24
# 27          40.00   26
# 28           8.00   25
# 29           5.00   34
# ..            ...  ...
# 431         10.00   27
# 432          4.00   30
# 433          3.00   28
# 434          2.50   28
# 435          1.50   18
# 436          0.25   19
# 437          1.50   34
# 438          1.00   26
# ...
