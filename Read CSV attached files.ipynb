# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("hubble_data.csv")

# %%
data.head()
# Out:
#    distance  recession_velocity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185

# %%
data.describe()
# Out:
#         distance  recession_velocity
# count  24.000000           24.000000
# mean    0.911375          373.125000
# std     0.645496          371.254666
# min     0.032000         -220.000000
# 25%     0.406250          165.000000
# 50%     0.900000          295.000000
# 75%     1.175000          537.500000
# max     2.000000         1090.000000

# %%
data.rename(columns={'distance':'dist','recession_velocity':'reces_vel'},inplace=True)

# %%
data
# Out:
#      dist  reces_vel
# 0   0.032        170
# 1   0.034        290
# 2   0.214       -130
# 3   0.263        -70
# 4   0.275       -185
# 5   0.275       -220
# 6   0.450        200
# 7   0.500        290
# 8   0.500        270
# 9   0.630        200
# 10  0.800        300
# 11  0.900        -30
# 12  0.900        650
# 13  0.900        150
# 14  0.900        500
# 15  1.000        920
# 16  1.100        450
# 17  1.100        500
# 18  1.400        500
# 19  1.700        960
# 20  2.000        500
# 21  2.000        850
# 22  2.000        800
# 23  2.000       1090

# %%
data.plot('dist','reces_vel')

# %%
data.sort_values('dist')
data.sort_values('reces_vel')
# Out:
#      dist  reces_vel
# 5   0.275       -220
# 4   0.275       -185
# 2   0.214       -130
# 3   0.263        -70
# 11  0.900        -30
# 13  0.900        150
# 0   0.032        170
# 9   0.630        200
# 6   0.450        200
# 8   0.500        270
# 7   0.500        290
# 1   0.034        290
# 10  0.800        300
# 16  1.100        450
# 14  0.900        500
# 17  1.100        500
# 18  1.400        500
# 20  2.000        500
# 12  0.900        650
# 22  2.000        800
# 21  2.000        850
# 15  1.000        920
# 19  1.700        960
# 23  2.000       1090

# %%
data.sort_index()
# Out:
#      dist  reces_vel
# 0   0.032        170
# 1   0.034        290
# 2   0.214       -130
# 3   0.263        -70
# 4   0.275       -185
# 5   0.275       -220
# 6   0.450        200
# 7   0.500        290
# 8   0.500        270
# 9   0.630        200
# 10  0.800        300
# 11  0.900        -30
# 12  0.900        650
# 13  0.900        150
# 14  0.900        500
# 15  1.000        920
# 16  1.100        450
# 17  1.100        500
# 18  1.400        500
# 19  1.700        960
# 20  2.000        500
# 21  2.000        850
# 22  2.000        800
# 23  2.000       1090
